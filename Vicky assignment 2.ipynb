# %% [markdown]
# List

# %%
lst = ["vicky", 12345,1605,[3, 6,9,3]]

# %%
lst
# Out:
# ['vicky', 12345, 1605, [3, 6, 9, 3]]

# %%
lst[0]
# Out:
# 'vicky'

# %%
lst[1]
# Out:
# 12345

# %%
lst[2]
# Out:
# 1605

# %%
lst[3][2]
# Out:
# 9

# %%
lst.append("razor")

# %%
lst
# Out:
# ['vicky', 12345, 1605, [3, 6, 9, 3], 'razor']

# %%
lst[-1]
# Out:
# 'razor'

# %%
lst[-2][1]
# Out:
# 6

# %%
lst.reverse()

# %%
lst
# Out:
# ['razor', [3, 6, 9, 3], 1605, 12345, 'vicky']

# %%
lst.remove("razor")

# %%
lst
# Out:
# [[3, 6, 9, 3], 1605, 12345, 'vicky']

# %%
lst.insert(2,"chennai ")

# %%
lst
# Out:
# [[3, 6, 9, 3], 1605, 'chennai ', 12345, 'vicky']

# %%
lst.count("1605")
# Out:
# 0

# %%
lst
# Out:
# [[3, 6, 9, 3], 1605, 'chennai ', 12345, 'vicky']

# %% [markdown]
# Dictionaries

# %%
dit ={"name":"vicky", "age":"21", "number":"123456789","email":"vickymuthu42@gmail.com"}

# %%
dit
# Out:
# {'age': '21',
#  'email': 'vickymuthu42@gmail.com',
#  'name': 'vicky',
#  'number': '123456789'}

# %%
dit["name"]
# Out:
# 'vicky'

# %%
dit["age"]
# Out:
# '21'

# %%
dit.items()
# Out:
# dict_items([('name', 'vicky'), ('age', '21'), ('number', '123456789'), ('email', 'vickymuthu42@gmail.com')])

# %%
dit.keys()
# Out:
# dict_keys(['name', 'age', 'number', 'email'])

# %%
dit.pop("name")
# Out:
# 'vicky'

# %%
dit.values()
# Out:
# dict_values(['21', '123456789', 'vickymuthu42@gmail.com'])

# %%
dit.popitem()
# Out:
# ('email', 'vickymuthu42@gmail.com')

# %% [markdown]
# Set

# %%
st ={"vicky ","chennai",1,2,3,8,4,1,9,4}

# %%
st
# Out:
# {1, 2, 3, 4, 8, 9, 'chennai', 'vicky '}

# %%
st1 ={"radax","vicky", 1,3,4}

# %%
st1
# Out:
# {1, 3, 4, 'radax', 'vicky'}

# %%
st1.issubset(st)
# Out:
# False

# %%
st1.isdisjoint(st)
# Out:
# False

# %%
st1.intersection_update(st)

# %%
st
# Out:
# {1, 2, 3, 4, 8, 9, 'chennai', 'vicky '}

# %%
st1
# Out:
# {1, 3, 4}

# %%
st1.intersection(st)
# Out:
# {1, 3, 4}

# %%
st1.difference_update(st)

# %%
st
# Out:
# {1, 2, 3, 4, 8, 9, 'chennai', 'vicky '}

# %%
st1

# %% [markdown]
# Tuple

# %%
tup =("vickymuthu","@","gmail.com")

# %%
tup
# Out:
# ('vickymuthu', '@', 'gmail.com')

# %%
tup. index("@")
# Out:
# 1

# %%
tup.index("vickymuthu")
# Out:
# 0

# %%
tup.count("gmail.com")
# Out:
# 1

# %% [markdown]
# String

# %%
name = 'vicky'
name2 = 'vicky'

# %%
name2
# Out:
# 'vicky'

# %%
name + " " +name2
# Out:
# 'vicky vicky'

# %%
name.capitalize()
# Out:
# 'Vicky'

# %%
name.center(20)
# Out:
# '       vicky        '
